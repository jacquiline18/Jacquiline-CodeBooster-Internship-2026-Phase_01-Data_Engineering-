# %% [markdown]
# <a href="https://colab.research.google.com/github/jacquiline18/Jacquiline-CodeBooster-Internship-2026-Phase_01-Data_Engineering-/blob/main/Day_04_Housing_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("Pandas Imported Successfully!")
# Out:
# Pandas Imported Successfully!

# %%
df = pd.read_csv("Housing.csv")

print("Dataset Loaded Successfully!")
# Out:
# Dataset Loaded Successfully!

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
print(df.shape)
# Out:
# (545, 13)

# %%
print("Number of Rows :", df.shape[0])
# Out:
# Number of Rows : 545

# %%
print("Number of Columns :", df.shape[1])
# Out:
# Number of Columns : 13

# %%
print(df.columns)
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
for col in df.columns:
    print(col)
# Out:
# price
# area
# bedrooms
# bathrooms
# stories
# mainroad
# guestroom
# basement
# hotwaterheating
# airconditioning
# parking
# prefarea
# furnishingstatus

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
print(df.isnull().sum())
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
print("Duplicate Rows :", df.duplicated().sum())
# Out:
# Duplicate Rows : 0

# %%
print("=" * 50)

print("HOUSING DATASET ANALYSIS COMPLETED")

print("=" * 50)

print("Rows :", df.shape[0])

print("Columns :", df.shape[1])

print("Dataset checked successfully")
# Out:
# ...
# HOUSING DATASET ANALYSIS COMPLETED
# ...
# Rows : 545
# Columns : 13
# Dataset checked successfully

# %%
print(df.dtypes)
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
print("Main Road:", df['mainroad'].unique())

print("Guest Room:", df['guestroom'].unique())

print("Basement:", df['basement'].unique())

print("Furnishing Status:", df['furnishingstatus'].unique())
# Out:
# Main Road: ['yes' 'no']
# Guest Room: ['no' 'yes']
# Basement: ['no' 'yes']
# Furnishing Status: ['furnished' 'semi-furnished' 'unfurnished']

# %%
print("Average House Price :", df['price'].mean())
# Out:
# Average House Price : 4766729.247706422

# %%
print("Maximum House Price :", df['price'].max())
# Out:
# Maximum House Price : 13300000

# %%
print("Minimum House Price :", df['price'].min())
# Out:
# Minimum House Price : 1750000

# %%
df.corr(numeric_only=True)
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
import matplotlib.pyplot as plt

plt.hist(df['price'], bins=20)

plt.xlabel("House Price")

plt.ylabel("Count")

plt.title("House Price Distribution")

plt.show()

# %%
print("=" * 60)

print("HOUSING DATASET HOME ASSIGNMENT COMPLETED")

print("=" * 60)

print("Rows :", df.shape[0])

print("Columns :", df.shape[1])

print("Missing Values Checked")

print("Duplicate Values Checked")

print("Statistical Analysis Completed")

print("Price Analysis Completed")

print("Visualization Completed")
# Out:
# ...
# HOUSING DATASET HOME ASSIGNMENT COMPLETED
# ...
# Rows : 545
# Columns : 13
# Missing Values Checked
# Duplicate Values Checked
# Statistical Analysis Completed
# Price Analysis Completed
# Visualization Completed
